# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df['Installs'].describe()
# Out:
# count          10841
# unique            22
# top       1,000,000+
# freq            1579
# Name: Installs, dtype: object

# %%
df.Rating.describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
df2 = df.sort_values(
    'Installs',ascending=False
).sort_values('Reviews', ascending = False)

# %%
df2[0:3]
# Out:
#                                App  Category  Rating Reviews Size    Installs  \
# 2989        GollerCepte Live Score    SPORTS     4.2    9992  31M  1,000,000+
# 4970  Ad Block REMOVER - NEED ROOT     TOOLS     3.3     999  91k    100,000+
# 2705           SnipSnap Coupon App  SHOPPING     4.2    9975  18M  1,000,000+
#
#       Type Price Content Rating    Genres       Last Updated Current Ver  \
# 2989  Free     0       Everyone    Sports       May 23, 2018         6.5
# 4970  Free     0       Everyone     Tools  December 17, 2013         3.2
# 2705  Free     0       Everyone  Shopping   January 22, 2018         1.4
#
#      Android Ver
# 2989  4.1 and up
# 4970  2.2 and up
# 2705  4.3 and up

# %%
df2 = df.sort_values('Installs',ascending=False)

# controllo quante sono le app con il valore massimo di download

topapps = np.where(df['Installs'] == '500,000,000+')
print('')
print('Le app più scaricate sono: ' + str(len(topapps[0])))
print('')
# Out:
# Le app più scaricate sono: 72

# %%
categorical = df.dtypes[df.dtypes== 'object'].index
df[categorical].describe()
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %%
df.Price.apply(lambda x: float(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/b1/3kx90hls3vb6pt3yflbcnlh40000gn/T/ipykernel_37781/1709272526.py in <cell line: 1>()
# ----> 1 df.Price.apply(lambda x: float(x))
#
# ~/.pyenv/versions/3.10.9/envs/prova/lib/python3.10/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/.pyenv/versions/3.10.9/envs/prova/lib/python3.10/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/.pyenv/versions/3.10.9/envs/prova/lib/python3.10/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/.pyenv/versions/3.10.9/envs/prova/lib/python3.10/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/b1/3kx90hls3vb6pt3yflbcnlh40000gn/T/ipykernel_37781/1709272526.py in <lambda>(x)
# ----> 1 df.Price.apply(lambda x: float(x))
#
# ValueError: could not convert string to float: '$4.99'

# %%
# Cleaning steps: trasformare variabili object in numeriche dove possibile

### Cleaning Reviews variable
STEP DA FARE QUI


### Cleaning Rating 
una con 1


### Price 
def remove_dollars(x):
    mi trova il simbolo dollaro
    me lo leva
    return numero senza dollaro
    
df.Price.apply(lambda x: remove_dollars(x)).apply(lambda x: float(x))

# %%
class Preprocessing:
    
    def __init__(self):
        pass
    
    def remove_dollars(self, x):
        mi trova il simbolo dollaro
        me lo leva
        return numero senza dollaro
    
    def convert_price_to_numeric(self, df):
        # solo alla colonna prezzo
        df.Price.apply(lambda x: self.remove_dollars(x)).apply(lambda x: float(x))
        return df
# Out:
#   File "/var/folders/b1/3kx90hls3vb6pt3yflbcnlh40000gn/T/ipykernel_37781/3931450640.py", line 7
#     mi trova il simbolo dollaro
#        ^
# SyntaxError: invalid syntax

# %%
pp = Preprocessing()

df = read_csv(...)

# cleaning di price
df_cleaned = pp.convert_price_to_numeric(df)

# cleaning di ratings
df_cleaned_2 = pp.clean_ratings(df_cleaned)
