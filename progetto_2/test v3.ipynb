# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Alessio\Desktop\Progetti Team 1\develhope_2023_team1\progetto_2\database\googleplaystore.csv')
# Row totally mistaken, dropping row 10472

# %%
df['Installs'].describe()
# Out:
# count          10841
# unique            22
# top       1,000,000+
# freq            1579
# Name: Installs, dtype: object

# %%
df.Rating.describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = df.assign(Installs = pd.to_numeric(df['Installs'].str.replace('[^0-9.]', '',regex=True)))
# delete string from size, changing M to 000000, changing k to 000, assign median to empty values
df.loc[df["Size"] == "Varies with device", "Size"] = ''
df.Size = df.Size.str.replace('M','000000',regex=True)
df.Size = df.Size.str.replace('k','000',regex=True)
df = df.assign(Size = pd.to_numeric(df['Size'].str.replace('[^0-9.]', '',regex=True)))
df = df.assign(Price = pd.to_numeric(df['Price'].str.replace('[^0-9.]', '',regex=True)))

# %%
df2.groupby(by='Installs').count()
# Out:
#                App  Category  Rating  Reviews  Size  Type  Price  \
# Installs
# 0.000000e+00    15        15       0       15    14    14     15
# 1.000000e+00    67        67       3       67    64    67     67
# 5.000000e+00    82        82       9       82    78    82     82
# 1.000000e+01   386       386      69      386   376   386    386
# 5.000000e+01   205       205      56      205   201   205    205
# 1.000000e+02   719       719     309      719   702   719    719
# 5.000000e+02   330       330     201      330   322   330    330
# 1.000000e+03   907       907     713      907   873   907    907
# 5.000000e+03   477       477     432      477   461   477    477
# 1.000000e+04  1054      1054    1010     1054  1011  1054   1054
# 5.000000e+04   479       479     467      479   446   479    479
# 1.000000e+05  1169      1169    1150     1169  1054  1169   1169
# 5.000000e+05   539       539     538      539   492   539    539
# ...

# %%
df2 = df.sort_values(['Installs','Rating'],ascending=[False,False])

# controllo quante sono le app con il valore massimo di download

#topapps = df2.head()[ [df2['Installs'] == max(df2['Installs'])] ]
#print('')
#print('Le app più scaricate sono: ' + str(len(topapps[0])))
#print('')

# %%
categorical = df.dtypes[df.dtypes== 'object'].index
df[categorical].describe()
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %%
df3 = df2.drop_duplicates(
  subset = ['App'],
  keep = 'first').reset_index(drop = True)

# %%
df3
# Out:
#                                           App       Category  Rating  \
# 0                              Subway Surfers           GAME     4.5
# 1                                   Instagram         SOCIAL     4.5
# 2                               Google Photos    PHOTOGRAPHY     4.5
# 3                          WhatsApp Messenger  COMMUNICATION     4.4
# 4                                      Google          TOOLS     4.4
# ...                                       ...            ...     ...
# 9655                             EP Cook Book        MEDICAL     NaN
# 9656                              Eu sou Rico        FINANCE     NaN
# 9657                              Eu Sou Rico        FINANCE     NaN
# 9658        I'm Rich/Eu sou Rico/أنا غني/我很有錢      LIFESTYLE     NaN
# 9659  Life Made WI-Fi Touchscreen Photo Frame            1.9    19.0
#
#        Reviews        Size      Installs  Type   Price Content Rating  \
# ...

# %%
# Cleaning steps: trasformare variabili object in numeriche dove possibile

### Cleaning Reviews variable
STEP DA FARE QUI


### Cleaning Rating 
una con 1


### Price 
def remove_dollars(x):
    mi trova il simbolo dollaro
    me lo leva
    return numero senza dollaro
    
df.Price.apply(lambda x: remove_dollars(x)).apply(lambda x: float(x))

# %%
class Preprocessing:
    
    def __init__(self):
        pass
    
    def remove_dollars(self, x):
        mi trova il simbolo dollaro
        me lo leva
        return numero senza dollaro
    
    def convert_price_to_numeric(self, df):
        # solo alla colonna prezzo
        df.Price.apply(lambda x: self.remove_dollars(x)).apply(lambda x: float(x))
        return df
# Out:
#   File "/var/folders/b1/3kx90hls3vb6pt3yflbcnlh40000gn/T/ipykernel_37781/3931450640.py", line 7
#     mi trova il simbolo dollaro
#        ^
# SyntaxError: invalid syntax

# %%
pp = Preprocessing()

df = read_csv(...)

# cleaning di price
df_cleaned = pp.convert_price_to_numeric(df)

# cleaning di ratings
df_cleaned_2 = pp.clean_ratings(df_cleaned)

# %%
topapps
# Out:
# (array([ 342,  347,  371,  378,  383,  385,  403,  420,  431,  465,  467,
#          474, 1655, 1661, 1662, 1702, 1705, 1722, 1729, 1751, 1759, 1842,
#         1869, 1885, 1886, 1908, 1920, 1966, 2546, 2550, 2603, 2610, 3235,
#         3255, 3265, 3326, 3450, 3473, 3476, 3522, 3533, 3562, 3569, 3574,
#         3703, 3711, 3739, 3755, 3767, 3796, 3819, 3870, 3879, 3888, 3907,
#         3934, 3971, 3994, 4005, 4039, 4041, 4048, 4105, 4115, 4122, 4147,
#         4222, 4365, 4566, 4676, 5596, 7536], dtype=int64),)

# %%
df_rev = pd.read_csv(r'C:\Users\Alessio\Desktop\Progetti Team 1\develhope_2023_team1\progetto_2\database\googleplaystore_user_reviews.csv')

# %%
my_df = df_rev [ df_rev['App'].str.contains('instagram')]

# %%
df_rev
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...
